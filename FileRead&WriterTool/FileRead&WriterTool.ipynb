# %% [markdown]
# <a href="https://colab.research.google.com/github/iavishagupta/AgenticTools-Basics-/blob/main/FileRead%26WriterTool/FileRead%26WriterTool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install crewai[tools] > /dev/null
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %%
import os
from google.colab import userdata

os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
from crewai import Agent, Task, Crew
from crewai_tools import FileReadTool, FileWriterTool

# %%
read_tool = FileReadTool()
write_tool = FileWriterTool()

# %%
writer = Agent(
    role='Content Writer',
    goal='Write and read content to and from files',
    backstory='You are an experienced file reader and writer who can manipulate content as required.',
    tools=[read_tool, write_tool],
    verbose=True
    )

# %%
write_task = Task(
    description='Write a welcome message to a file.',
    agent=writer,
    expected_output='File "welcome.txt" containing the welcome message.'
)

crew = Crew(agents=[writer], tasks=[write_task])
crew.kickoff()
# Out:
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Content Writer                                                       │
# │                                                                              │
# │  Task: Write a welcome message to a file.                                    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────── 🔧 Agent Tool Execution ───────────────────────────╮
# │                                                                              │
# │  Agent: Content Writer                                                       │
# │                                                                              │
# │  Thought: Thought: I need to write a welcome message to the file named       │
# ...

# %%
read_task = Task(
    description='Read the content from "welcome.txt".',
    agent=writer,
    expected_output='Content of the file "welcome.txt".'
)

crew = Crew(agents=[writer], tasks=[read_task])
crew.kickoff()
# Out:
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Content Writer                                                       │
# │                                                                              │
# │  Task: Read the content from "welcome.txt".                                  │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────── 🔧 Agent Tool Execution ───────────────────────────╮
# │                                                                              │
# │  Agent: Content Writer                                                       │
# │                                                                              │
# │  Thought: Thought: I need to read the entire content of the file             │
# ...
